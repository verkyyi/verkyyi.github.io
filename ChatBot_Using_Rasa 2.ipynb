# %% [markdown]
# ---
# title: "Making chatbots using RASA"
# format: revealjs
# ---

# %% [markdown]
# ## Chatbots
#
# Popular chatbos
#
# - Siri
#
# - Alexa
#
# - ChatGpt
#
# ## Use Cases
#
# Why can we use chatbots for?
#
# - Customer Service (FAQ)
#
# - Insurance Sales (Lenmonade, conversational)
#
# ![](./Lemonade.png)
#
# ## What is Rasa
#
# With over 25 million downloads, Rasa Open Source is the most popular open source framework for building chat and voice-based AI assistants.
#
# - NLU determines what the user wants and captures key contextual information
#
# - Core: selects the next best response or action based on conversation history
#
# - Channels and integrations: connect assistant to users and backend systems
#
# ::: aside
# https://rasa.com/docs/rasa/img/introduction.png
# https://medium.com/analytics-vidhya/build-a-chatbot-using-rasa-78406306aa0c
# :::
#
# ## How does Rasa work?
#
# ![image.png](https://rasa.com/docs/rasa/img/architecture.png)
#
# ::: aside
# https://miro.medium.com/v2/resize:fit:1400/format:webp/1*7NgKCr08twnoQ8Ls2ircxA.png
# :::
#
# ## Setup
#
# First make sure your pip version is up to date:
# ```shell
# pip3 install -U pip
# ```
#
# ## Install Rasa Open Source#
#
# Instally Rasa Open Source
# ```shell
# pip3 install rasa
# ```
#
# Notes: Python 3.11> is not supported, you should downgrade to early version or using conda to switch.
#
# ## Command Line Interface
#
# - rasa init (create a new project)
# - rasa train  (train a model)
# - rasa shell  (talk to your assistant)
# - rasa interactive  (teach your assistant with interactive learning)
#
# ::: aside
# https://rasa.com/docs/rasa/command-line-interface
# :::
#
# ## Custom models
#
# - Conversation-Driven Development
#   Best Practice
# - Generating NLU Data
# - Writing Conversation Stories
#
# Notes
# Share your assistant with users as soon as possible
# Review conversations on a regular basis
# Annotate messages and use them as NLU training data
# Test that your assistant always behaves as you expect
# Track when your assistant fails and measure its performance over time
# Fix how your assistant handles unsuccessful conversations
#
# ## Train your models
#
# - Rules
# - Storys
# - Policies
# - Intents
# - Entities
#
# > rasa data validate
# > rasa train
#
# Intents: What Does the User Say. Rasa uses the concept of intents to describe how user messages should be categorized.
# Response: How the bot replies to the query. If you want your bot to respond to user messages, you need to manage the bot’s responses.
# Story: It is a representation of a conversation between a user and an AI assistant, converted into a specific format where user inputs are expressed as corresponding intents while the responses of an assistant are expressed as corresponding action names.
#
# ## Conversation Patterns
#
# - Chitchat and FAQs
# - Business Logic
# - Fallback and Human handoff
# - Contextual Conversations
#
# ## Debug
#
# ![](./descision_graph.png)
#
# ## Interactive Learning
#
# ![](./interactive_mode.png)
#
# ## Deploy and Publish to Channel
#
# - Deploying to Cloud
#   Google Cloud/AWS/Azure
# - Discord
# - Telegram
# - Slack
#
# ## Demo
#
# A simple chatbot that can help you answer questions from your girl friend.
#
# > rasa run locally on command line.
# ![](./rasa_shell.png)
#
# ## Summary
#
# - Rasa is a powerful open source framework for building chatbots.
# - You can build your own chatbot using Rasa.
# - Rule based priority is higher than ML based priority.
# - Deploy first and adapt later.
#
# ## References
